# %% [markdown]
# # ROS2 - Introducing Tutlesim
#
# **Goal**: Use the turtlesim package and rqt tools to prepare for upcoming tutorials.
#
# **Tutorial level**: Beginner
#
# ## Background
# Turtlesim is a lightweight simulator for learning ROS 2. It illustrates what ROS 2 does at the most basic level to give you an idea of what you will do with a real robot or a robot simulation later on.
#
# The ros2 tool is how the user manages, introspects, and interacts with a ROS system. It supports multiple commands that target different aspects of the system and its operation. One might use it to start a node, set a parameter, listen to a topic, and many more. The ros2 tool is part of the core ROS 2 installation.
#
# rqt is a graphical user interface (GUI) tool for ROS 2. Everything done in rqt can be done on the command line, but rqt provides a more user-friendly way to manipulate ROS 2 elements.
#
# This tutorial touches upon core ROS 2 concepts, like nodes, topics, and services. All of these concepts will be elaborated on in later tutorials; for now, you will simply set up the tools and get a feel for them.
#
# Source: [Introducing-Turtlesim](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Introducing-Turtlesim/Introducing-Turtlesim.html)

# %% [markdown]
# ## Display a remote desktop

# %%
from utils import display_desktop
display_desktop()

# %% [markdown]
# ## Open terminals
#
# You can either open terminals in the JupyterLab launcher or the remote desktop.

# %% [markdown]
# ## Check that the turtlesim package is installed
#
# Run the following command in the terminal:
# ```bash
# ros2 pkg executables turtlesim
# ```
#
# Expected output:
# ```
# turtlesim draw_square
# turtlesim mimic
# turtlesim turtle_teleop_key
# turtlesim turtlesim_node
# ```

# %% [markdown]
# ## Start turtlesim
#
# To start turtlesim, enter the following command in your terminal:
#
# ```bash
# ros2 run turtlesim turtlesim_node
# ```
#
# The simulator window should appear in the desktop, with a random turtle in the center.
#
# ![image.png](attachment:879714a8-94f4-409d-9c58-095408bce1da.png)

# %% [markdown]
# ## Use turtlesim
# Open a new terminal and run a new node to control the turtle in the first node:
# ```bash
# ros2 run turtlesim turtle_teleop_key
# ```
# Use the arrow keys on your keyboard to control the turtle. It will move around the screen, using its attached “pen” to draw the path it followed so far.

# %% [markdown]
# ## `ros2` commands
#
# > Code start with `!` in Jupyter notebook will be executed as bash commands
#
# You can see the nodes, and their associated topics, services, and actions, using the `list` subcommands of the respective commands:

# %% [markdown]
# ### ros2 node
# Learn more about nodes: [Understanding nodes](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Nodes/Understanding-ROS2-Nodes.html)

# %%
# List nodes
# !ros2 node list
# Out:
# /teleop_turtle
# /turtlesim

# %%
# Get details of node /turtlesim
# !ros2 node info /turtlesim
# Out:
# /turtlesim
#   Subscribers:
#     /parameter_events: rcl_interfaces/msg/ParameterEvent
#     /turtle1/cmd_vel: geometry_msgs/msg/Twist
#   Publishers:
#     /parameter_events: rcl_interfaces/msg/ParameterEvent
#     /rosout: rcl_interfaces/msg/Log
#     /turtle1/color_sensor: turtlesim/msg/Color
#     /turtle1/pose: turtlesim/msg/Pose
#   Service Servers:
#     /clear: std_srvs/srv/Empty
#     /kill: turtlesim/srv/Kill
#     /reset: std_srvs/srv/Empty
#     /spawn: turtlesim/srv/Spawn
#     /turtle1/set_pen: turtlesim/srv/SetPen
#     /turtle1/teleport_absolute: turtlesim/srv/TeleportAbsolute
#     /turtle1/teleport_relative: turtlesim/srv/TeleportRelative
#     /turtlesim/describe_parameters: rcl_interfaces/srv/DescribeParameters
#     /turtlesim/get_parameter_types: rcl_interfaces/srv/GetParameterTypes
#     /turtlesim/get_parameters: rcl_interfaces/srv/GetParameters
#     /turtlesim/list_parameters: rcl_interfaces/srv/ListParameters
#     /turtlesim/set_parameters: rcl_interfaces/srv/SetParameters
#     /turtlesim/set_parameters_atomically: rcl_interfaces/srv/SetParametersAtomically
#   Service Clients:
#
#   Action Servers:
#     /turtle1/rotate_absolute: turtlesim/action/RotateAbsolute
#   Action Clients:

# %% [markdown]
# ### ros2 topic
#
# Learn more about topics: [Understanding topics](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Topics/Understanding-ROS2-Topics.html)

# %%
# List topics
# !ros2 topic list
# Out:
# /parameter_events
# /rosout
# /turtle1/cmd_vel
# /turtle1/color_sensor
# /turtle1/pose

# %%
# Inspect topic
# !ros2 topic info /turtle1/cmd_vel
# Out:
# Type: geometry_msgs/msg/Twist
# Publisher count: 1
# Subscription count: 1

# %%
# Use GUI tool `rqt_graph`
# !rqt_graph
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-jovyan'
# ^C
# [INFO] [1715948394.447459557] [rclcpp]: signal_handler(signum=2)

# %% [markdown]
# ### ros2 service
# Learn more about services: [Understanding services](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Services/Understanding-ROS2-Services.html)

# %%
# list services
# !ros2 service list
# Out:
# /clear
# /kill
# /reset
# /spawn
# /teleop_turtle/describe_parameters
# /teleop_turtle/get_parameter_types
# /teleop_turtle/get_parameters
# /teleop_turtle/list_parameters
# /teleop_turtle/set_parameters
# /teleop_turtle/set_parameters_atomically
# /turtle1/set_pen
# /turtle1/teleport_absolute
# /turtle1/teleport_relative
# /turtlesim/describe_parameters
# /turtlesim/get_parameter_types
# /turtlesim/get_parameters
# /turtlesim/list_parameters
# /turtlesim/set_parameters
# /turtlesim/set_parameters_atomically

# %%
# Use GUI tool `rqt`
# !rqt
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-jovyan'
# ^C
# [INFO] [1715948408.746375415] [rclcpp]: signal_handler(signum=2)

# %% [markdown]
# #### Service Caller
# Select **Plugins > Services > Service Caller** from the menu bar at the top.
#
# Try out calling different services.
#
# ![image.png](attachment:2784a8d8-912f-401a-bdbc-b54b5d9c74ba.png)
#
# More beginner tutorials can be found in [ROS2 documentation](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools.html).

# %% [markdown]
# ### ros2 param
# Learn more about parameters: [Understanding parameters](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Parameters/Understanding-ROS2-Parameters.html)

# %%
# List paramters
# !ros2 param list
# Out:
# /teleop_turtle:
#   qos_overrides./parameter_events.publisher.depth
#   qos_overrides./parameter_events.publisher.durability
#   qos_overrides./parameter_events.publisher.history
#   qos_overrides./parameter_events.publisher.reliability
#   scale_angular
#   scale_linear
#   use_sim_time
# /turtlesim:
#   background_b
#   background_g
#   background_r
#   qos_overrides./parameter_events.publisher.depth
#   qos_overrides./parameter_events.publisher.durability
#   qos_overrides./parameter_events.publisher.history
#   qos_overrides./parameter_events.publisher.reliability
#   use_sim_time

# %%
# Get values of parameters
# !ros2 param get /turtlesim background_r
# !ros2 param get /turtlesim background_b
# !ros2 param get /turtlesim background_g
# Out:
# Integer value is: 69
# Integer value is: 255
# Integer value is: 86

# %%
# Set values of parameters
# !ros2 param set /turtlesim background_r 180
# !ros2 param set /turtlesim background_g 100
# !ros2 param set /turtlesim background_b 100
# Out:
# Set parameter successful
# Set parameter successful
# Set parameter successful

# %% [markdown]
# ### ros2 actions
#
# Learn more about actions: [Understanding actions](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Understanding-ROS2-Actions/Understanding-ROS2-Actions.html)

# %%
# list actions
# !ros2 action list
# list actions with types
# !ros2 action list -t
# Out:
# /turtle1/rotate_absolute
# /turtle1/rotate_absolute [turtlesim/action/RotateAbsolute]

# %%
# action info
# !ros2 action info /turtle1/rotate_absolute
# Out:
# Action: /turtle1/rotate_absolute
# Action clients: 1
#     /teleop_turtle
# Action servers: 1
#     /turtlesim

# %%
# Structure of the action type
# !ros2 interface show turtlesim/action/RotateAbsolute
# Out:
# # The desired heading in radians
# float32 theta
# ---
# # The angular displacement in radians to the starting position
# float32 delta
# ---
# # The remaining rotation in radians
# float32 remaining

# %%
 # send an action goal
# !ros2 action send_goal /turtle1/rotate_absolute turtlesim/action/RotateAbsolute "{theta: 1.57}"
# Out:
# Waiting for an action server to become available...
# Sending goal:
#      theta: 1.57
#
# Goal accepted with ID: c25d0eecd50e4151b67c20815cf069b8
#
# Result:
#     delta: -2.5280001163482666
#
# Goal finished with status: SUCCEEDED

# %%
 # send an action goal with feedback
# !ros2 action send_goal /turtle1/rotate_absolute turtlesim/action/RotateAbsolute "{theta: -1.57}" --feedback
# Out:
# Waiting for an action server to become available...
# Sending goal:
#      theta: -1.57
#
# Goal accepted with ID: ca98b7a09b2f4ab7b75c65868fccac22
#
# Feedback:
#     remaining: -3.134888172149658
#
# Feedback:
#     remaining: -3.1188883781433105
#
# Feedback:
#     remaining: -3.1028881072998047
#
# Feedback:
#     remaining: -3.086888313293457
#
# Feedback:
#     remaining: -3.0708882808685303
#
# Feedback:
#     remaining: -3.0548882484436035
#
# Feedback:
#     remaining: -3.0388882160186768
#
# Feedback:
#     remaining: -3.02288818359375
#
# Feedback:
#     remaining: -3.0068883895874023
#
# Feedback:
#     remaining: -2.9908881187438965
#
# Feedback:
#     remaining: -2.974888324737549
#
# Feedback:
#     remaining: -2.958888292312622
#
# Feedback:
#     remaining: -2.9428882598876953
#
# Feedback:
#     remaining: -2.9268882274627686
#
# Feedback:
#     remaining: -2.910888195037842
#
# Feedback:
#     remaining: -2.894888401031494
#
# Feedback:
#     remaining: -2.8788881301879883
#
# Feedback:
#     remaining: -2.8628883361816406
#
# Feedback:
#     remaining: -2.846888303756714
#
# Feedback:
#     remaining: -2.830888271331787
#
# Feedback:
#     remaining: -2.8148882389068604
#
# Feedback:
#     remaining: -2.7988882064819336
#
# Feedback:
#     remaining: -2.782888412475586
#
# Feedback:
#     remaining: -2.76688814163208
#
# Feedback:
#     remaining: -2.7508883476257324
#
# Feedback:
#     remaining: -2.7348880767822266
#
# Feedback:
#     remaining: -2.718888282775879
#
# Feedback:
#     remaining: -2.702888250350952
#
# Feedback:
#     remaining: -2.6868882179260254
#
# Feedback:
#     remaining: -2.6708884239196777
#
# Feedback:
#     remaining: -2.654888153076172
#
# Feedback:
#     remaining: -2.638888359069824
#
# Feedback:
#     remaining: -2.6228880882263184
#
# Feedback:
#     remaining: -2.6068882942199707
#
# Feedback:
#     remaining: -2.590888261795044
#
# Feedback:
#     remaining: -2.574888229370117
#
# Feedback:
#     remaining: -2.5588881969451904
#
# Feedback:
#     remaining: -2.5428881645202637
#
# Feedback:
#     remaining: -2.526888370513916
#
# Feedback:
#     remaining: -2.5108883380889893
#
# Feedback:
#     remaining: -2.4948883056640625
#
# Feedback:
#     remaining: -2.4788882732391357
#
# Feedback:
#     remaining: -2.462888240814209
#
# Feedback:
#     remaining: -2.4468882083892822
#
# Feedback:
#     remaining: -2.4308881759643555
#
# Feedback:
#     remaining: -2.414888381958008
#
# Feedback:
#     remaining: -2.398888111114502
#
# Feedback:
#     remaining: -2.3828883171081543
#
# Feedback:
#     remaining: -2.3668882846832275
#
# Feedback:
#     remaining: -2.350888252258301
#
# Feedback:
#     remaining: -2.334888219833374
#
# Feedback:
#     remaining: -2.3188881874084473
#
# Feedback:
#     remaining: -2.3028883934020996
#
# Feedback:
#     remaining: -2.2868881225585938
#
# Feedback:
#     remaining: -2.270888328552246
#
# Feedback:
#     remaining: -2.2548882961273193
#
# Feedback:
#     remaining: -2.2388882637023926
#
# Feedback:
#     remaining: -2.222888231277466
#
# Feedback:
#     remaining: -2.206888198852539
#
# Feedback:
#     remaining: -2.1908881664276123
#
# Feedback:
#     remaining: -2.1748881340026855
#
# Feedback:
#     remaining: -2.158888339996338
#
# Feedback:
#     remaining: -2.142888307571411
#
# Feedback:
#     remaining: -2.1268882751464844
#
# Feedback:
#     remaining: -2.1108882427215576
#
# Feedback:
#     remaining: -2.094888210296631
#
# Feedback:
#     remaining: -2.078888177871704
#
# Feedback:
#     remaining: -2.0628881454467773
#
# Feedback:
#     remaining: -2.0468883514404297
#
# Feedback:
#     remaining: -2.030888319015503
#
# Feedback:
#     remaining: -2.014888286590576
#
# Feedback:
#     remaining: -1.9988882541656494
#
# Feedback:
#     remaining: -1.9828882217407227
#
# Feedback:
#     remaining: -1.966888189315796
#
# Feedback:
#     remaining: -1.9508882761001587
#
# Feedback:
#     remaining: -1.934888243675232
#
# Feedback:
#     remaining: -1.9188882112503052
#
# Feedback:
#     remaining: -1.902888298034668
#
# Feedback:
#     remaining: -1.8868882656097412
#
# Feedback:
#     remaining: -1.8708882331848145
#
# Feedback:
#     remaining: -1.8548882007598877
#
# Feedback:
#     remaining: -1.8388882875442505
#
# Feedback:
#     remaining: -1.8228882551193237
#
# Feedback:
#     remaining: -1.806888222694397
#
# Feedback:
#     remaining: -1.7908883094787598
#
# Feedback:
#     remaining: -1.774888277053833
#
# Feedback:
#     remaining: -1.7588882446289062
#
# Feedback:
#     remaining: -1.7428882122039795
#
# Feedback:
#     remaining: -1.7268882989883423
#
# Feedback:
#     remaining: -1.7108882665634155
#
# Feedback:
#     remaining: -1.6948882341384888
#
# Feedback:
#     remaining: -1.678888201713562
#
# Feedback:
#     remaining: -1.6628882884979248
#
# Feedback:
#     remaining: -1.646888256072998
#
# Feedback:
#     remaining: -1.6308882236480713
#
# Feedback:
#     remaining: -1.6148881912231445
#
# Feedback:
#     remaining: -1.5988882780075073
#
# Feedback:
#     remaining: -1.5828882455825806
#
# Feedback:
#     remaining: -1.5668882131576538
#
# Feedback:
#     remaining: -1.5508882999420166
#
# Feedback:
#     remaining: -1.5348882675170898
#
# Feedback:
#     remaining: -1.518888235092163
#
# Feedback:
#     remaining: -1.5028882026672363
#
# Feedback:
#     remaining: -1.4868882894515991
#
# Feedback:
#     remaining: -1.4708882570266724
#
# Feedback:
#     remaining: -1.4548882246017456
#
# Feedback:
#     remaining: -1.4388883113861084
#
# Feedback:
#     remaining: -1.4228882789611816
#
# Feedback:
#     remaining: -1.4068882465362549
#
# Feedback:
#     remaining: -1.3908882141113281
#
# Feedback:
#     remaining: -1.374888300895691
#
# Feedback:
#     remaining: -1.3588882684707642
#
# Feedback:
#     remaining: -1.3428882360458374
#
# Feedback:
#     remaining: -1.3268882036209106
#
# Feedback:
#     remaining: -1.3108882904052734
#
# Feedback:
#     remaining: -1.2948882579803467
#
# Feedback:
#     remaining: -1.27888822555542
#
# Feedback:
#     remaining: -1.2628881931304932
#
# Feedback:
#     remaining: -1.246888279914856
#
# Feedback:
#     remaining: -1.2308882474899292
#
# Feedback:
#     remaining: -1.2148882150650024
#
# Feedback:
#     remaining: -1.1988883018493652
#
# Feedback:
#     remaining: -1.1828882694244385
#
# Feedback:
#     remaining: -1.1668882369995117
#
# Feedback:
#     remaining: -1.150888204574585
#
# Feedback:
#     remaining: -1.1348882913589478
#
# Feedback:
#     remaining: -1.118888258934021
#
# Feedback:
#     remaining: -1.1028882265090942
#
# Feedback:
#     remaining: -1.086888313293457
#
# Feedback:
#     remaining: -1.0708882808685303
#
# Feedback:
#     remaining: -1.0548882484436035
#
# Feedback:
#     remaining: -1.0388882160186768
#
# Feedback:
#     remaining: -1.02288818359375
#
# Feedback:
#     remaining: -1.0068882703781128
#
# Feedback:
#     remaining: -0.990888237953186
#
# Feedback:
#     remaining: -0.974888265132904
#
# Feedback:
#     remaining: -0.9588882327079773
#
# Feedback:
#     remaining: -0.9428882598876953
#
# Feedback:
#     remaining: -0.9268882274627686
#
# Feedback:
#     remaining: -0.9108882546424866
#
# Feedback:
#     remaining: -0.8948882818222046
#
# Feedback:
#     remaining: -0.8788882493972778
#
# Feedback:
#     remaining: -0.8628882765769958
#
# Feedback:
#     remaining: -0.8468882441520691
#
# Feedback:
#     remaining: -0.8308882713317871
#
# Feedback:
#     remaining: -0.8148882389068604
#
# Feedback:
#     remaining: -0.7988882660865784
#
# Feedback:
#     remaining: -0.7828882336616516
#
# Feedback:
#     remaining: -0.7668882608413696
#
# Feedback:
#     remaining: -0.7508882284164429
#
# Feedback:
#     remaining: -0.7348882555961609
#
# Feedback:
#     remaining: -0.7188882231712341
#
# Feedback:
#     remaining: -0.7028882503509521
#
# Feedback:
#     remaining: -0.6868882775306702
#
# Feedback:
#     remaining: -0.6708882451057434
#
# Feedback:
#     remaining: -0.6548882722854614
#
# Feedback:
#     remaining: -0.6388882398605347
#
# Feedback:
#     remaining: -0.6228882670402527
#
# Feedback:
#     remaining: -0.6068882346153259
#
# Feedback:
#     remaining: -0.590888261795044
#
# Feedback:
#     remaining: -0.5748882293701172
#
# Feedback:
#     remaining: -0.5588881969451904
#
# Feedback:
#     remaining: -0.5428882837295532
#
# Feedback:
#     remaining: -0.5268882513046265
#
# Feedback:
#     remaining: -0.5108882188796997
#
# Feedback:
#     remaining: -0.4948883056640625
#
# Feedback:
#     remaining: -0.47888827323913574
#
# Feedback:
#     remaining: -0.462888240814209
#
# Feedback:
#     remaining: -0.4468882083892822
#
# Feedback:
#     remaining: -0.430888295173645
#
# Feedback:
#     remaining: -0.41488826274871826
#
# Feedback:
#     remaining: -0.3988882303237915
#
# Feedback:
#     remaining: -0.38288819789886475
#
# Feedback:
#     remaining: -0.36688828468322754
#
# Feedback:
#     remaining: -0.3508882522583008
#
# Feedback:
#     remaining: -0.334888219833374
#
# Feedback:
#     remaining: -0.3188883066177368
#
# Feedback:
#     remaining: -0.30288827419281006
#
# Feedback:
#     remaining: -0.2868882417678833
#
# Feedback:
#     remaining: -0.27088820934295654
#
# Feedback:
#     remaining: -0.25488829612731934
#
# Feedback:
#     remaining: -0.23888826370239258
#
# Feedback:
#     remaining: -0.22288823127746582
#
# Feedback:
#     remaining: -0.20688819885253906
#
# Feedback:
#     remaining: -0.19088828563690186
#
# Feedback:
#     remaining: -0.1748882532119751
#
# Feedback:
#     remaining: -0.15888822078704834
#
# Feedback:
#     remaining: -0.14288830757141113
#
# Feedback:
#     remaining: -0.12688827514648438
#
# Feedback:
#     remaining: -0.11088824272155762
#
# Feedback:
#     remaining: -0.09488821029663086
#
# Feedback:
#     remaining: -0.07888829708099365
#
# Feedback:
#     remaining: -0.0628882646560669
#
# Feedback:
#     remaining: -0.04688823223114014
#
# Feedback:
#     remaining: -0.03088819980621338
#
# Feedback:
#     remaining: -0.014888286590576172
#
# Result:
#     delta: 3.119999885559082
#
# Goal finished with status: SUCCEEDED

# %% [markdown]
# ### Using `rqt_console` to view logs
#
# `rqt_console` is a GUI tool used to introspect log messages in ROS 2.
#
# Open a new terminal and run:
#
# ```bash
# ros2 run rqt_console rqt_console
# ```
#
# Learn more: [Using rqt_console to view logs](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Using-Rqt-Console/Using-Rqt-Console.html)

# %%
# Send message in loop and check the logs in rqt_console
# !ros2 topic pub -r 1 /turtle1/cmd_vel geometry_msgs/msg/Twist "{linear: {x: 2.0, y: 0.0, z: 0.0}, angular: {x: 0.0,y: 0.0,z: 0.0}}"
# Out:
# publisher: beginning loop
# publishing #1: geometry_msgs.msg.Twist(linear=geometry_msgs.msg.Vector3(x=2.0, y=0.0, z=0.0), angular=geometry_msgs.msg.Vector3(x=0.0, y=0.0, z=0.0))
#
# publishing #2: geometry_msgs.msg.Twist(linear=geometry_msgs.msg.Vector3(x=2.0, y=0.0, z=0.0), angular=geometry_msgs.msg.Vector3(x=0.0, y=0.0, z=0.0))
#
# publishing #3: geometry_msgs.msg.Twist(linear=geometry_msgs.msg.Vector3(x=2.0, y=0.0, z=0.0), angular=geometry_msgs.msg.Vector3(x=0.0, y=0.0, z=0.0))
#
# ^C

# %% [markdown]
# ### ros2 launch
#
# Use a command line tool to launch multiple nodes at once.
#
# Open a new terminal and run:
#
# ```bash
# ros2 launch turtlesim multisim.launch.py
# ```
#
# Source code of launch file `multisim.launch.py`:
# ```python
# # turtlesim/launch/multisim.launch.py
# from launch import LaunchDescription
# import launch_ros.actions
#
# def generate_launch_description():
#     return LaunchDescription([
#         launch_ros.actions.Node(
#             namespace= "turtlesim1", package='turtlesim', executable='turtlesim_node', output='screen'),
#         launch_ros.actions.Node(
#             namespace= "turtlesim2", package='turtlesim', executable='turtlesim_node', output='screen'),
#     ])
# ```
#
# Learn more: [Launching nodes](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Launching-Multiple-Nodes/Launching-Multiple-Nodes.html)

# %%
# Control the first turtle
# !ros2 topic pub /turtlesim1/turtle1/cmd_vel geometry_msgs/msg/Twist "{linear: {x: 2.0, y: 0.0, z: 0.0}, angular: {x: 0.0, y: 0.0, z: 1.8}}"

# %%
# Control the second turtle
# !ros2 topic pub  /turtlesim2/turtle1/cmd_vel geometry_msgs/msg/Twist "{linear: {x: 2.0, y: 0.0, z: 0.0}, angular: {x: 0.0, y: 0.0, z: -1.8}}"

# %% [markdown]
# ### ros2 bag
#
# Record data published on a topic so you can replay and examine it any time.
#
# Start the `turtlesim_node` and `turtle_teleop_key` in terminal again:
#
# ```bash
# ros2 run turtlesim turtlesim_node
# ```
#
# ```bash
# ros2 run turtlesim turtle_teleop_key
# ```
#
# Learn more: [Recording and playing back data](https://docs.ros.org/en/jazzy/Tutorials/Beginner-CLI-Tools/Recording-And-Playing-Back-Data/Recording-And-Playing-Back-Data.html)

# %%
# Choose a topic
# !ros2 topic list
# Out:
# /parameter_events
# /rosout
# /turtle1/cmd_vel
# /turtle1/color_sensor
# /turtle1/pose

# %%
# Record a single topic
# !ros2 bag record -o rosbag2_mybag /turtle1/cmd_vel
# Out:
# [INFO] [1715948520.500898965] [rosbag2_recorder]: Press SPACE for pausing/resuming
# [INFO] [1715948520.501784999] [rosbag2_storage]: Opened database 'rosbag2_mybag/rosbag2_mybag_0.db3' for READ_WRITE.
# [INFO] [1715948520.502130680] [rosbag2_recorder]: Listening for topics...
# [INFO] [1715948520.502137899] [rosbag2_recorder]: Event publisher thread: Starting
# [INFO] [1715948520.502914233] [rosbag2_recorder]: Subscribed to topic '/turtle1/cmd_vel'
# [INFO] [1715948520.502952181] [rosbag2_recorder]: Recording...
# [INFO] [1715948520.503041908] [rosbag2_recorder]: All requested topics are subscribed. Stopping discovery...
# [INFO] [1715948531.550883104] [rosbag2_cpp]: Writing remaining messages from cache to the bag. It may take a while
# [INFO] [1715948531.551349984] [rosbag2_recorder]: Event publisher thread: Exiting
# [INFO] [1715948531.551395586] [rosbag2_recorder]: Recording stopped

# %% [markdown]
# Under on the terminal window running `turtle_teleop_key` control the turtle to move around with arrow key, and then stop the recording code cell above.
#
# You should see a new directory with a name `ros2bag_mybag` created.

# %%
# Check the info of the ros bag file
# !ros2 bag info rosbag2_mybag
# Out:
# Files:             rosbag2_mybag_0.db3
# Bag size:          33.0 KiB
# Storage id:        sqlite3
# Duration:          3.66s
# Start:             May 17 2024 12:22:06.838 (1715948526.838)
# End:               May 17 2024 12:22:09.904 (1715948529.904)
# Messages:          70
# Topic information: Topic: /turtle1/cmd_vel | Type: geometry_msgs/msg/Twist | Count: 70 | Serialization Format: cdr

# %%
# Play the ros bag file
# !ros2 bag play rosbag2_mybag
# Out:
# [INFO] [1715948537.505846534] [rosbag2_storage]: Opened database 'rosbag2_mybag/rosbag2_mybag_0.db3' for READ_ONLY.
# [INFO] [1715948537.505880898] [rosbag2_player]: Set rate to 1
# [INFO] [1715948537.508197932] [rosbag2_player]: Adding keyboard callbacks.
# [INFO] [1715948537.508214748] [rosbag2_player]: Press SPACE for Pause/Resume
# [INFO] [1715948537.508221883] [rosbag2_player]: Press CURSOR_RIGHT for Play Next Message
# [INFO] [1715948537.508228049] [rosbag2_player]: Press CURSOR_UP for Increase Rate 10%
# [INFO] [1715948537.508233663] [rosbag2_player]: Press CURSOR_DOWN for Decrease Rate 10%
# [INFO] [1715948537.508454028] [rosbag2_storage]: Opened database 'rosbag2_mybag/rosbag2_mybag_0.db3' for READ_ONLY.

# %% [markdown]
# ### Summary
#
# You’ve completed the “ROS2 Beginner: CLI Tools” tutorials! The next step is tackling the “Beginner: Client Libraries” tutorials, starting with Creating a workspace.
